# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Ejercicio del perro
x =[0.,.25,.5,.75,1.] #Son tres conjutos de datos distintos
a = [np.cos(np.pi*0),np.cos(np.pi*.25),np.cos(np.pi*.5),np.cos(np.pi*.75),np.cos(np.pi*1.)] #f(x)
dfx0=0  #Condiciones de frontera 
dfxn=0

# %%
x_arrays=[]
y_arrays=[]

for k in range(len(x)):
    x_array = np.linspace(min(x[k]),max(x[k]),100)
    y_array = []

    n=len(x[k])-1
    for i in range(0,len(x_array)):
        for j in range(0,n):
            if x[k][j]<=x_array[i]<x[k][j+1]:
                s = a[k][j]+b_lists[k][j]*(x_array[i]-x[k][j]) + c_lists[k][j]*(x_array[i]-x[k][j])**2 + d_lists[k][j]*(x_array[i]-x[k][j])**3
                y_array.append(s)
        if x_array[i]==x[k][n]:
            s = a[k][n]+b_lists[k][n]*(x_array[i]-x[k][n]) + c_lists[k][n]*(x_array[i]-x[k][n])**2 + d_lists[k][n]*(x_array[i]-x[k][n])**3
            y_array.append(s)
    for i in x_array:
        x_arrays.append(i)
    for i in y_array:
        y_arrays.append(i)
x_real=
y_real=[]


fig=plt.figure(figsize=(30,8))
ax=plt.axes()
ax.grid()
ax.plot(x_arrays,y_arrays)
plt.show()
